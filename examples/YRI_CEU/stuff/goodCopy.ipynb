# %%
# %matplotlib notebook
import GPy
import GPyOpt

from GPyOpt.methods import BayesianOptimization

import GPy_Test as test

import numpy as np
import matplotlib.pyplot as plt
from functools import partial

# %%
test.run(0)
# Out:
# num acquisition: 1, time elapsed: 0.67s
# num acquisition: 2, time elapsed: 1.32s
# num acquisition: 3, time elapsed: 2.01s
# num acquisition: 4, time elapsed: 2.68s
# num acquisition: 5, time elapsed: 3.53s
# num acquisition: 6, time elapsed: 4.36s
# num acquisition: 7, time elapsed: 5.08s
# num acquisition: 8, time elapsed: 5.90s
# num acquisition: 9, time elapsed: 6.78s
# num acquisition: 10, time elapsed: 7.58s
# The minimum value obtained by the function was 1066.8215
# (param[0] = [1.87106006])

# %%
# opt.plot_convergence()
test.run(1)
# Out:
# num acquisition: 1, time elapsed: 0.53s
# num acquisition: 2, time elapsed: 1.05s
# num acquisition: 3, time elapsed: 1.55s
# num acquisition: 4, time elapsed: 2.09s
# num acquisition: 5, time elapsed: 2.62s
# num acquisition: 6, time elapsed: 3.14s
# num acquisition: 7, time elapsed: 3.66s
# num acquisition: 8, time elapsed: 4.20s
# num acquisition: 9, time elapsed: 4.74s
# num acquisition: 10, time elapsed: 5.28s
# The minimum value obtained by the function was 1074.1498
# (param[1] = [0.0672941])

# %%
test.run(2)
# Out:
# num acquisition: 1, time elapsed: 0.40s
# num acquisition: 2, time elapsed: 0.92s
# num acquisition: 3, time elapsed: 1.60s
# num acquisition: 4, time elapsed: 2.43s
# num acquisition: 5, time elapsed: 3.21s
# num acquisition: 6, time elapsed: 3.95s
# num acquisition: 7, time elapsed: 4.80s
# num acquisition: 8, time elapsed: 5.51s
# num acquisition: 9, time elapsed: 6.21s
# num acquisition: 10, time elapsed: 6.91s
# The minimum value obtained by the function was 3428.7671
# (param[2] = [1.])

# %%
test.run(3)
# Out:
# num acquisition: 1, time elapsed: 0.78s
# num acquisition: 2, time elapsed: 1.36s
# num acquisition: 3, time elapsed: 1.85s
# num acquisition: 4, time elapsed: 2.51s
# num acquisition: 5, time elapsed: 3.13s
# num acquisition: 6, time elapsed: 3.75s
# num acquisition: 7, time elapsed: 4.31s
# num acquisition: 8, time elapsed: 4.93s
# num acquisition: 9, time elapsed: 5.68s
# num acquisition: 10, time elapsed: 6.26s
# The minimum value obtained by the function was 3731.7882
# (param[3] = [0.01])

# %%
test.run(4)
# Out:
# num acquisition: 1, time elapsed: 0.64s
# num acquisition: 2, time elapsed: 1.22s
# num acquisition: 3, time elapsed: 1.80s
# num acquisition: 4, time elapsed: 2.32s
# num acquisition: 5, time elapsed: 2.88s
# num acquisition: 6, time elapsed: 3.36s
# num acquisition: 7, time elapsed: 3.88s
# num acquisition: 8, time elapsed: 4.42s
# num acquisition: 9, time elapsed: 4.90s
# num acquisition: 10, time elapsed: 5.48s
# The minimum value obtained by the function was 4539.8803
# (param[4] = [0.1165376])

# %%
test.run(5)
# Out:
# num acquisition: 1, time elapsed: 0.60s
# num acquisition: 2, time elapsed: 1.10s
# num acquisition: 3, time elapsed: 1.74s
# num acquisition: 4, time elapsed: 2.33s
# num acquisition: 5, time elapsed: 2.88s
# num acquisition: 6, time elapsed: 3.48s
# num acquisition: 7, time elapsed: 4.09s
# num acquisition: 8, time elapsed: 4.65s
# num acquisition: 9, time elapsed: 5.24s
# num acquisition: 10, time elapsed: 5.80s
# The minimum value obtained by the function was 2665.7831
# (param[5] = [0.53697564])
